# %% [markdown]
# # Overview
#
# We're now switching focus away from Network Science (for a little bit), beginning to think about _Natural Language Processing_ instead. In other words, today will be all about teaching your computer to "understand" text. This ties in nicely with our work on the rappers network, since it is built on the rapper Wikipedia pages which contain pieces of text. We've looked at the network so far - now, let's see if we can include the text. Today is about
#
# * Installing the _natural language toolkit_ (NLTK) package and learning the basics of how it works (Chapter 1)
# * Figuring out how to make NLTK to work with other types of text (Chapter 2).
#
# > _Reading_
# > The reading for today is Natural Language Processing with Python (NLPP) Chapter 1 and 2. [It's free online](http://www.nltk.org/book/).

# %% [markdown]
# # Part 1: A little lecture
#
# > [**_Video Lecture_**](https://www.dropbox.com/scl/fi/vj2h6pekdl6y8yid070y5/NLP_Intro.mp4?rlkey=kajuxgfl413ql3q1qwdrqf9ok&dl=0). Today is all about ***working*** with NLTK, so not much lecturing - just a few words on NLP.

# %% [markdown]
# # Part 2: Installing and the basics

# %% [markdown]
# ## 2.1 NLTK Install tips
#
# Check to see if `nltk` is installed on your system by typing `import nltk` in a `notebook`. If it's not already installed, install it as part of _Anaconda_ by typing
#
#      conda install nltk
#
# at the command prompt. If you don't have them, you can download the various corpora using a command-line version of the downloader that runs in Python notebooks (as mentioned in Ch. 1 Sec. 1.2 of the book):
#
# In the Jupyter notebook, run the code
#
#  `import nltk`
#
#  `nltk.download()`
#
# Now you can hit `d` to download, then type "book" to fetch the collection needed today's `nltk` session. Now that everything is up and running, let's get to the actual exercises.
#
# **Note**: If, instead of opening the pop-up, your Kernel dies, you can direclty download the collection by typing `nltk.download("book")` instead.

# %%
import nltk
nltk.download()

# %% [markdown]
# ## 2.2 Introduction to NLTK

# %% [markdown]
# 1. Now that you have `nltk` installed, work through Chapter 1, Sections 1 to 4. The book is set up as a kind of tutorial with lots of examples for you to work through. I recommend you read the text with an open Jupyter Notebook and type out the examples that you see. ***It becomes much more fun if you add a few variations and see what happens***. We tweaked some of these examples in the following exercises and they might very well be due as assignments, so those ones should definitely be in a `notebook`.

# %%
from nltk.book import *

# %%
text1

# %%
text2

# %%
text1.concordance("pictures")

# %%
text1.concordance("moby")

# %%
text5.similar("lol")

# %%
text7.common_contexts(["money", "stocks"])

# %%
text7.dispersion_plot(["money", "america", "stocks", "news", "local"])

# %%
text7.generate()

# %%
text1.generate()

# %%
len(text2)

# %%
sorted(set(text4)) # words and other tokens

# %%
text5.count("lol")

# %%
100 * text5.count('lol') / len(text5) # percentage of "lol" in total text

# %% [markdown]
# 2. Now that you have gone through Chapter 1, let's try some of the `nltk` functionalities on our own Text!
#
# > Setup. We want to start from a clean version of the rapper Wikipedia pages. A version with as little wiki-markup as possible. We needed it earlier to get the links, but now we want a readable version. To do this we need to create 10 new regex patterns and parse the pages ...
# >
# > No! Don't worry! We can get a fairly nice version directly from the Wikipedia API. Follow the instructions below:
# >
# > * read the [csv file](https://github.com/SocialComplexityLab/socialgraphs2023/blob/main/files/Rappers.csv) of the rappers with pandas `pd.read_csv()` and assign it to `df_rappers`, but change the parameters that you use to call the api to:
#     - `"action": "query"`
#     - `"prop": "extracts"`,
#     - `"exlimit":"1"`,
#     - `"explaintext": "1"`,
#     - `"format": "json"`,
#     - `"titles": [INSERT NAME OF THE RAPPER]`
# > * loop through the `Name` column of `df_rappers` and for each name make a request to the API
# >     * **Note1** if you are using the `urllib`, replace white spaces with `_` and use `urllib.parse.quote_plus(NAME_OF_RAPPER_HERE)` to build your title;
# > * after using `json` to load the text, remember to get the value (the clean text we are looking for) from the right key
# >     * **Note2** the key you are looking for is now `extract` and not `*`; check that your code gets the right page (you may have to do a manual exploration of the json structure again.
# >
# > Use this method to retrieve a nice copy of all rappers' text. Save each rapper's text in a txt file and collect them all in a new folder!

# %%
# An attempt that may or may not work, but I forgot to make a folder before running it

# import pywikibot
# import os
# import pandas as pd

# wiki = pywikibot.Site('en', 'wikipedia')

# df_rappers = pd.read_csv("../../files/Rappers.csv")

# for rapper in df_rappers["WikipediaPageName"]:
#     params = {
#         "action": "query",
#         "prop": "extracts",
#         "exlimit": "1",
#         "explaintext": "1",
#         "format": "json",
#         "titles": rapper
#     }
#     request = pywikibot.data.api.Request(site=wiki, parameters=params)
#     response = request.submit()
#     page = next(iter(response['query']['pages'].values()))
#     try:
#         with open(f"../data/clean/{rapper}.txt", "w", encoding="utf-8") as f:
#             f.write(page['extract'])
#     except Exception as e:
#         print(f"Failed to save the page: {rapper}.")
# Out:
# File 6ix9ine.txt already exists. Skipping.
# File 9th Prince.txt already exists. Skipping.
# File 22Gz.txt already exists. Skipping.
# File 38 Spesh.txt already exists. Skipping.
# File The 45 King.txt already exists. Skipping.
# File 50 Cent.txt already exists. Skipping.
# File 60 Second Assassin (rapper).txt already exists. Skipping.
# File 88-Keys.txt already exists. Skipping.
# File Sammy Adams.txt already exists. Skipping.
# File Adeem (rapper).txt already exists. Skipping.
# File Aesop Rock.txt already exists. Skipping.
# File Afu-Ra.txt already exists. Skipping.
# File Akir.txt already exists. Skipping.
# File Akrobatik.txt already exists. Skipping.
# File Alias (musician).txt already exists. Skipping.
# File Hoodie Allen.txt already exists. Skipping.
# File Amil.txt already exists. Skipping.
# File Antoinette (rapper).txt already exists. Skipping.
# File Aone Beats.txt already exists. Skipping.
# File Apache (rapper).txt already exists. Skipping.
# File Apathy (rapper).txt already exists. Skipping.
# File AR-Ab.txt already exists. Skipping.
# File AraabMuzik.txt already exists. Skipping.
# File Arkatech Beatz.txt already exists. Skipping.
# File M. K. Asante.txt already exists. Skipping.
# File Asheru.txt already exists. Skipping.
# File The Audible Doctor.txt already exists. Skipping.
# File Awkwafina.txt already exists. Skipping.
# File AZ (rapper).txt already exists. Skipping.
# File Apani B. Fly.txt already exists. Skipping.
# File DJ Babu.txt already exists. Skipping.
# File Bahamadia.txt already exists. Skipping.
# File Marty Baller.txt already exists. Skipping.
# File Charli Baltimore.txt already exists. Skipping.
# File Afrika Bambaataa.txt already exists. Skipping.
# File Bodega Bamz.txt already exists. Skipping.
# File Azealia Banks.txt already exists. Skipping.
# File Lloyd Banks.txt already exists. Skipping.
# File MC Paul Barman.txt already exists. Skipping.
# File Mark Batson.txt already exists. Skipping.
# File The Beat Bully.txt already exists. Skipping.
# File Jahlil Beats.txt already exists. Skipping.
# File Beedie (rapper).txt already exists. Skipping.
# File Benny the Butcher.txt already exists. Skipping.
# File Benzino.txt already exists. Skipping.
# File Big Body Bes.txt already exists. Skipping.
# File Big Daddy Kane.txt already exists. Skipping.
# File Big Pun.txt already exists. Skipping.
# File Big Shug.txt already exists. Skipping.
# File Bkorn.txt already exists. Skipping.
# File Black Child.txt already exists. Skipping.
# File Black Rob.txt already exists. Skipping.
# File Black Thought.txt already exists. Skipping.
# File Memphis Bleek.txt already exists. Skipping.
# File Blockhead (music producer).txt already exists. Skipping.
# File Action Bronson.txt already exists. Skipping.
# File Bronx Style Bob.txt already exists. Skipping.
# File Foxy Brown (rapper).txt already exists. Skipping.
# File Tommy Brown (record producer).txt already exists. Skipping.
# File Ron Browz.txt already exists. Skipping.
# File Buckshot (rapper).txt already exists. Skipping.
# File Buckwild (music producer).txt already exists. Skipping.
# File Joe Budden.txt already exists. Skipping.
# File Dai Burger.txt already exists. Skipping.
# File Cage (rapper).txt already exists. Skipping.
# File Crystal Caines.txt already exists. Skipping.
# File Call Me Ace.txt already exists. Skipping.
# File Cam'ron.txt already exists. Skipping.
# File Canibus.txt already exists. Skipping.
# File Don Cannon.txt already exists. Skipping.
# File Capella Grey.txt already exists. Skipping.
# File Capital Steez.txt already exists. Skipping.
# File Capone (rapper).txt already exists. Skipping.
# File Cappadonna.txt already exists. Skipping.
# File Kid Capri.txt already exists. Skipping.
# File Cardi B.txt already exists. Skipping.
# File Cardiak.txt already exists. Skipping.
# File Casanova (rapper).txt already exists. Skipping.
# File Cassidy (rapper).txt already exists. Skipping.
# File Grandmaster Caz.txt already exists. Skipping.
# File Cazwell.txt already exists. Skipping.
# File Lil' Cease.txt already exists. Skipping.
# File John Cena.txt already exists. Skipping.
# File Ceschi.txt already exists. Skipping.
# File DJ Charlie Chase.txt already exists. Skipping.
# File Chinx.txt already exists. Skipping.
# File DJ Chuck Chillout.txt already exists. Skipping.
# File Chyskillz.txt already exists. Skipping.
# File CJ (rapper).txt already exists. Skipping.
# File Clams Casino (musician).txt already exists. Skipping.
# File Sean Combs.txt already exists. Skipping.
# File Consequence (rapper).txt already exists. Skipping.
# File Conway the Machine.txt already exists. Skipping.
# File Cool C.txt already exists. Skipping.
# File Cordae.txt already exists. Skipping.
# File Cousin Stizz.txt already exists. Skipping.
# File Keef Cowboy.txt already exists. Skipping.
# File Jay Critch.txt already exists. Skipping.
# File Cuban Link.txt already exists. Skipping.
# File D-Nice.txt already exists. Skipping.
# File Daddy-O (rapper).txt already exists. Skipping.
# File Danger Mouse (musician).txt already exists. Skipping.
# File Danny Boy (rapper).txt already exists. Skipping.
# File Dash (rapper).txt already exists. Skipping.
# File Desiigner.txt already exists. Skipping.
# File Diabolic (rapper).txt already exists. Skipping.
# File Kosha Dillz.txt already exists. Skipping.
# File Flipp Dinero.txt already exists. Skipping.
# File Disco King Mario.txt already exists. Skipping.
# File DJ Disco Wiz.txt already exists. Skipping.
# File DMX.txt already exists. Skipping.
# File Tim Dog.txt already exists. Skipping.
# File B. Dolan.txt already exists. Skipping.
# File Don Q (rapper).txt already exists. Skipping.
# File MF Doom.txt already exists. Skipping.
# File Dot da Genius.txt already exists. Skipping.
# File Drag-On.txt already exists. Skipping.
# File DJ Drama.txt already exists. Skipping.
# File Dub-L.txt already exists. Skipping.
# File Dutch ReBelle.txt already exists. Skipping.
# File DVLP.txt already exists. Skipping.
# File Smoke DZA.txt already exists. Skipping.
# File E.D.I. Mean.txt already exists. Skipping.
# File East Flatbush Project.txt already exists. Skipping.
# File Dave East.txt already exists. Skipping.
# File Ed O.G..txt already exists. Skipping.
# File El-P.txt already exists. Skipping.
# File Eric B..txt already exists. Skipping.
# File Esoteric (rapper).txt already exists. Skipping.
# File Eve (rapper).txt already exists. Skipping.
# File Eyenine.txt already exists. Skipping.
# File Fabolous.txt already exists. Skipping.
# File Mickey Factz.txt already exists. Skipping.
# File Fat Joe.txt already exists. Skipping.
# File Hussein Fatal.txt already exists. Skipping.
# File Felly.txt already exists. Skipping.
# File ASAP Ferg.txt already exists. Skipping.
# File Grandmaster Flash.txt already exists. Skipping.
# File CJ Fly.txt already exists. Skipping.
# File Focus....txt already exists. Skipping.
# File Q Da Fool.txt already exists. Skipping.
# File Fivio Foreign.txt already exists. Skipping.
# File Freddie Foxxx.txt already exists. Skipping.
# File Njena Reddd Foxxx.txt already exists. Skipping.
# File Sage Francis.txt already exists. Skipping.
# File Harry Fraud.txt already exists. Skipping.
# File Fred the Godson.txt already exists. Skipping.
# File Freekey Zekey.txt already exists. Skipping.
# File Frenchie (rapper).txt already exists. Skipping.
# File Fresh Kid Ice.txt already exists. Skipping.
# File Doug E. Fresh.txt already exists. Skipping.
# File Funkmaster Flex.txt already exists. Skipping.
# File Ty Fyffe.txt already exists. Skipping.
# File G Koop.txt already exists. Skipping.
# File Heather B. Gardner.txt already exists. Skipping.
# File Mic Geronimo.txt already exists. Skipping.
# File GFMBryyce.txt already exists. Skipping.
# File Ghostface Killah.txt already exists. Skipping.
# File Godfather Don.txt already exists. Skipping.
# File Irv Gotti.txt already exists. Skipping.
# File Jean Grae.txt already exists. Skipping.
# File Grafh.txt already exists. Skipping.
# File Dame Grease.txt already exists. Skipping.
# File MF Grimm.txt already exists. Skipping.
# File Cory Gunz.txt already exists. Skipping.
# File Guru (rapper).txt already exists. Skipping.
# File GZA.txt already exists. Skipping.
# File Half a Mill.txt already exists. Skipping.
# File Sleepy Hallow.txt already exists. Skipping.
# File Charles Hamilton (rapper).txt already exists. Skipping.
# File Andre Harrell.txt already exists. Skipping.
# File Havoc (musician).txt already exists. Skipping.
# File Emile Haynie.txt already exists. Skipping.
# File Heavy D.txt already exists. Skipping.
# File Hell Rell.txt already exists. Skipping.
# File Samuel T. Herring.txt already exists. Skipping.
# File Chad Hugo.txt already exists. Skipping.
# File DJ Hurricane.txt already exists. Skipping.
# File Ice Spice.txt already exists. Skipping.
# File Ill Bill.txt already exists. Skipping.
# File Inspectah Deck.txt already exists. Skipping.
# File Islord.txt already exists. Skipping.
# File J.I the Prince of N.Y.txt already exists. Skipping.
# File J57 (rapper).txt already exists. Skipping.
# File Ja Rule.txt already exists. Skipping.
# File Jadakiss.txt already exists. Skipping.
# File Ms. Jade.txt already exists. Skipping.
# File Mike Jaggerr.txt already exists. Skipping.
# File Jam Master Jay.txt already exists. Skipping.
# File Jasiri X.txt already exists. Skipping.
# File Jay-Z.txt already exists. Skipping.
# File Jaz-O.txt already exists. Skipping.
# File MC Jazzy Jeff.txt already exists. Skipping.
# File DJ Jazzy Joyce.txt already exists. Skipping.
# File MC Jin.txt already exists. Skipping.
# File Jipsta.txt already exists. Skipping.
# File Joey Badass.txt already exists. Skipping.
# File Chilla Jones.txt already exists. Skipping.
# File Serius Jones.txt already exists. Skipping.
# File JPEGMafia.txt already exists. Skipping.
# File Junglepussy.txt already exists. Skipping.
# File Just Blaze.txt already exists. Skipping.
# File Just-Ice.txt already exists. Skipping.
# File Ka$hdami.txt already exists. Skipping.
# File Kangol Kid.txt already exists. Skipping.
# File Kastro (rapper).txt already exists. Skipping.
# File DJ Kay Slay.txt already exists. Skipping.
# File Kemba (rapper).txt already exists. Skipping.
# File Jamie Kennedy.txt already exists. Skipping.
# File Wiz Khalifa.txt already exists. Skipping.
# File Killa Sin.txt already exists. Skipping.
# File Kirk Knight.txt already exists. Skipping.
# File Tate Kobang.txt already exists. Skipping.
# File Kool G Rap.txt already exists. Skipping.
# File Kool Moe Dee.txt already exists. Skipping.
# File KRS-One.txt already exists. Skipping.
# File Talib Kweli.txt already exists. Skipping.
# File Big L.txt already exists. Skipping.
# File Coke La Rock.txt already exists. Skipping.
# File Scott La Rock.txt already exists. Skipping.
# File Lady B.txt already exists. Skipping.
# File Lady Crush.txt already exists. Skipping.
# File Al Sherrod Lambert.txt already exists. Skipping.
# File Lamiere.txt already exists. Skipping.
# File Knero Lapaé.txt already exists. Skipping.
# File Larry Larr.txt already exists. Skipping.
# File Sabor Latino.txt already exists. Skipping.
# File Lee on the Beats.txt already exists. Skipping.
# File HeeSun Lee.txt already exists. Skipping.
# File Trip Lee.txt already exists. Skipping.
# File Le1f.txt already exists. Skipping.
# File Johan Lenox.txt already exists. Skipping.
# File Coi Leray.txt already exists. Skipping.
# File Alrad Lewis.txt already exists. Skipping.
# File Rob Lewis (record producer).txt already exists. Skipping.
# File Mr. Lif.txt already exists. Skipping.
# File Like (record producer).txt already exists. Skipping.
# File Lil Dicky.txt already exists. Skipping.
# File Lil Mama.txt already exists. Skipping.
# File Lil Peep.txt already exists. Skipping.
# File Lil Tjay.txt already exists. Skipping.
# File Lil' Kim.txt already exists. Skipping.
# File Lin Que.txt already exists. Skipping.
# File Ex-plicit linez.txt already exists. Skipping.
# File Dusty Locane.txt already exists. Skipping.
# File Nicholas Loftin.txt already exists. Skipping.
# File DJ Logic.txt already exists. Skipping.
# File Sheek Louch.txt already exists. Skipping.
# File Louis Logic.txt already exists. Skipping.
# File Ed Lover.txt already exists. Skipping.
# File Jan Lucanus.txt already exists. Skipping.
# File Joyner Lucas.txt already exists. Skipping.
# File MC Lyte.txt already exists. Skipping.
# File M-Dot.txt already exists. Skipping.
# File Remy Ma.txt already exists. Skipping.
# File China Mac.txt already exists. Skipping.
# File Mach-Hommy.txt already exists. Skipping.
# File Craig Mack.txt already exists. Skipping.
# File Kellee Maize.txt already exists. Skipping.
# File Malik B..txt already exists. Skipping.
# File Roc Marciano.txt already exists. Skipping.
# File Biz Markie.txt already exists. Skipping.
# File Marley Marl.txt already exists. Skipping.
# File Brother Marquis.txt already exists. Skipping.
# File Skizzy Mars.txt already exists. Skipping.
# File Theo Martins.txt already exists. Skipping.
# File Mase.txt already exists. Skipping.
# File Masta Killa.txt already exists. Skipping.
# File Mathematics (producer).txt already exists. Skipping.
# File Ivan Matias.txt already exists. Skipping.
# File Lady May (rapper).txt already exists. Skipping.
# File Darryl McDaniels.txt already exists. Skipping.
# File McGruff (rapper).txt already exists. Skipping.
# File Megahertz (record producer).txt already exists. Skipping.
# File Melle Mel.txt already exists. Skipping.
# File Method Man.txt already exists. Skipping.
# File Mike D.txt already exists. Skipping.
# File Mikey D.txt already exists. Skipping.
# File Derrick Milano.txt already exists. Skipping.
# File Meek Mill.txt already exists. Skipping.
# File Mac Miller.txt already exists. Skipping.
# File Jae Millz.txt already exists. Skipping.
# File Mims (rapper).txt already exists. Skipping.
# File Andy Mineo.txt already exists. Skipping.
# File Mr. Muthafuckin' eXquire.txt already exists. Skipping.
# File Mr. Mixx.txt already exists. Skipping.
# File Easy Mo Bee.txt already exists. Skipping.
# File Pharoahe Monch.txt already exists. Skipping.
# File French Montana.txt already exists. Skipping.
# File Mos Def.txt already exists. Skipping.
# File Ali Shaheed Muhammad.txt already exists. Skipping.
# File Uncle Murda.txt already exists. Skipping.
# File Keith Murray.txt already exists. Skipping.
# File Myzery.txt already exists. Skipping.
# File N.O.R.E..txt already exists. Skipping.
# File Nas.txt already exists. Skipping.
# File ASAP Nast.txt already exists. Skipping.
# File Necro (rapper).txt already exists. Skipping.
# File Bishop Nehru.txt already exists. Skipping.
# File Neo da Matrix.txt already exists. Skipping.
# File Nine (rapper).txt already exists. Skipping.
# File Nitty (musician).txt already exists. Skipping.
# File No Malice.txt already exists. Skipping.
# File Young Noble.txt already exists. Skipping.
# File NOE (rapper).txt already exists. Skipping.
# File Princess Nokia.txt already exists. Skipping.
# File The Notorious B.I.G..txt already exists. Skipping.
# File O.C. (rapper).txt already exists. Skipping.
# File Ol' Dirty Bastard.txt already exists. Skipping.
# File Shaquille O'Neal.txt already exists. Skipping.
# File Oompa (rapper).txt already exists. Skipping.
# File Joell Ortiz.txt already exists. Skipping.
# File Styles P.txt already exists. Skipping.
# File Prince Paul (producer).txt already exists. Skipping.
# File Felicia Pearson.txt already exists. Skipping.
# File Pepa (rapper).txt already exists. Skipping.
# File Percee P.txt already exists. Skipping.
# File Pete Rock.txt already exists. Skipping.
# File Petey Pablo.txt already exists. Skipping.
# File Thee Phantom.txt already exists. Skipping.
# File Phife Dawg.txt already exists. Skipping.
# File Stelios Phili.txt already exists. Skipping.
# File Jamal Phillips.txt already exists. Skipping.
# File Phresher.txt already exists. Skipping.
# File Pras.txt already exists. Skipping.
# File DJ Premier.txt already exists. Skipping.
# File Sean Price.txt already exists. Skipping.
# File Prince Whipper Whip.txt already exists. Skipping.
# File Princess Superstar.txt already exists. Skipping.
# File Prodigy (rapper).txt already exists. Skipping.
# File Large Professor.txt already exists. Skipping.
# File Prolyphic.txt already exists. Skipping.
# File Pumpkinhead (rapper).txt already exists. Skipping.
# File Pusha T.txt already exists. Skipping.
# File Q-Tip (musician).txt already exists. Skipping.
# File Queen Latifah.txt already exists. Skipping.
# File Queen Pen.txt already exists. Skipping.
# File Radamiz.txt already exists. Skipping.
# File Rah Swish.txt already exists. Skipping.
# File Rakim.txt already exists. Skipping.
# File Kyle Rapps.txt already exists. Skipping.
# File Hell Razah.txt already exists. Skipping.
# File Oryn the Rebel.txt already exists. Skipping.
# File Red Café.txt already exists. Skipping.
# File Redman (rapper).txt already exists. Skipping.
# File Reks.txt already exists. Skipping.
# File Salaam Remi.txt already exists. Skipping.
# File Moshe Reuven.txt already exists. Skipping.
# File Busta Rhymes.txt already exists. Skipping.
# File DJ Richie Rich.txt already exists. Skipping.
# File Chubb Rock.txt already exists. Skipping.
# File Rockwilder.txt already exists. Skipping.
# File ASAP Rocky.txt already exists. Skipping.
# File Roscoe (rapper).txt already exists. Skipping.
# File Asher Roth.txt already exists. Skipping.
# File Elle Royal.txt already exists. Skipping.
# File David Rush (rapper).txt already exists. Skipping.
# File RZA.txt already exists. Skipping.
# File Sadat X.txt already exists. Skipping.
# File Saga (rapper).txt already exists. Skipping.
# File Saigon (rapper).txt already exists. Skipping.
# File Salt (rapper).txt already exists. Skipping.
# File Juelz Santana.txt already exists. Skipping.
# File Sauce Money.txt already exists. Skipping.
# File Scar Lip.txt already exists. Skipping.
# File Schoolly D.txt already exists. Skipping.
# File Jill Scott (singer).txt already exists. Skipping.
# File DJ Scratch.txt already exists. Skipping.
# File Sensational (musician).txt already exists. Skipping.
# File Sensato del Patio.txt already exists. Skipping.
# File Erick Sermon.txt already exists. Skipping.
# File Sha Money XL.txt already exists. Skipping.
# File Jonathan Shecter.txt already exists. Skipping.
# File Sheff G.txt already exists. Skipping.
# File Bobby Shmurda.txt already exists. Skipping.
# File Shock G.txt already exists. Skipping.
# File Kiing Shooter.txt already exists. Skipping.
# File Shyne.txt already exists. Skipping.
# File Beanie Sigel.txt already exists. Skipping.
# File Silkski.txt already exists. Skipping.
# File Siya.txt already exists. Skipping.
# File DJ Skee.txt already exists. Skipping.
# File Lil Skies.txt already exists. Skipping.
# File Skinnyfromthe9.txt already exists. Skipping.
# File Slaine (rapper).txt already exists. Skipping.
# File Rashad Smith (producer).txt already exists. Skipping.
# File Will Smith.txt already exists. Skipping.
# File Pop Smoke.txt already exists. Skipping.
# File CL Smooth.txt already exists. Skipping.
# File Sam Sneed.txt already exists. Skipping.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb Cell 24 line 2
#      <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=17'>18</a> params = {
#      <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=18'>19</a>     "action": "query",
#      <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=19'>20</a>     "prop": "extracts",
#    (...)
#      <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=23'>24</a>     "titles": rapper
#      <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=24'>25</a> }
#      <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=25'>26</a> request = pywikibot.data.api.Request(site=wiki, parameters=params)
# ---> <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=26'>27</a> response = request.submit()
#      <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=27'>28</a> page = next(iter(response['query']['pages'].values()))
#      <a href='vscode-notebook-cell:/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/Week6.ipynb#X45sZmlsZQ%3D%3D?line=28'>29</a> try:
#
# File ~/anaconda3/lib/python3.11/site-packages/pywikibot/data/api/_requests.py:985, in Request.submit(self)
#     982     return simulate
#     984 if self.throttle:
# --> 985     self.site.throttle(write=self.write)
#     986 else:
#     987     pywikibot.log(
#     988         f"Submitting unthrottled action '{self.action}'.")
#
# File ~/anaconda3/lib/python3.11/site-packages/pywikibot/throttle.py:282, in Throttle.__call__(self, requestsize, write)
#     280 lock = self.lock_write if write else self.lock_read
#     281 with lock:
# --> 282     wait = self.waittime(write=write)
#     283     # Calculate the multiplicity of the next delay based on how
#     284     # big the request is that is being posted now.
#     285     # We want to add "one delay" for each factor of two in the
#     286     # size of the request. Getting 64 pages at once allows 6 times
#     287     # the delay time for the server.
#     288     self.next_multiplicity = math.log(1 + requestsize) / math.log(2.0)
#
# File ~/anaconda3/lib/python3.11/site-packages/pywikibot/throttle.py:233, in Throttle.waittime(self, write)
#     227 """Return waiting time in seconds.
#     228
#     229 The result is for a query that would be made right now.
#     230 """
#     231 # Take the previous requestsize in account calculating the desired
#     232 # delay this time
# --> 233 thisdelay = self.getDelay(write=write)
#     234 now = time.time()
#     235 ago = now - (self.last_write if write else self.last_read)
#
# File ~/anaconda3/lib/python3.11/site-packages/pywikibot/throttle.py:217, in Throttle.getDelay(self, write)
#     215 # We're checking for multiple processes
#     216 if time.time() > self.checktime + self.checkdelay:
# --> 217     self.checkMultiplicity()
#     218 multiplied_delay = self.mindelay * self.next_multiplicity
#     219 if thisdelay < multiplied_delay:
#
# File ~/anaconda3/lib/python3.11/site-packages/pywikibot/throttle.py:153, in Throttle.checkMultiplicity(self)
#     150 count = 1
#     152 now = time.time()
# --> 153 for proc in self._read_file(raise_exc=True):
#     154     used_pids.add(proc.pid)
#     155     if now - proc.time > self.releasepid:
#
# File ~/anaconda3/lib/python3.11/site-packages/pywikibot/throttle.py:106, in Throttle._read_file(self, raise_exc)
#     104 """Yield process entries from file."""
#     105 try:
# --> 106     with open(self.ctrlfilename) as f:
#     107         lines = f.readlines()
#     108 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/madis/Dokumendid/GitHub/socialgraphs2023/lectures/Madis/throttle.ctrl'

# %%
import requests
import os
import pandas as pd

df_rappers = pd.read_csv("../../files/Rappers.csv")
baseurl = "http://en.wikipedia.org/w/api.php?"

for rapper in df_rappers["WikipediaPageName"]:
    file_path = f"../data/clean/{rapper}.txt"
    
    # Check if the file already exists
    if os.path.exists(file_path):
        print(f"File {rapper}.txt already exists. Skipping.")
        continue

    params = {
        "action": "query",
        "prop": "extracts",
        "exlimit": "1",
        "explaintext": "1",
        "format": "json",
        "titles": rapper
     }
    wikitext = requests.get(baseurl, params = params)
    wikijson = wikitext.json()
    num = list(wikijson['query']['pages'].keys())[0]
    text = wikijson['query']['pages'][num]['extract']
    try:
        with open(f"../data/clean/{rapper}.txt", "w", encoding="utf-8") as f:
            f.write(text)
    except Exception as e:
        print(f"Failed to save the page: {rapper}.")
# Out:
# File 6ix9ine.txt already exists. Skipping.
# File 9th Prince.txt already exists. Skipping.
# File 22Gz.txt already exists. Skipping.
# File 38 Spesh.txt already exists. Skipping.
# File The 45 King.txt already exists. Skipping.
# File 50 Cent.txt already exists. Skipping.
# File 60 Second Assassin (rapper).txt already exists. Skipping.
# File 88-Keys.txt already exists. Skipping.
# File Sammy Adams.txt already exists. Skipping.
# File Adeem (rapper).txt already exists. Skipping.
# File Aesop Rock.txt already exists. Skipping.
# File Afu-Ra.txt already exists. Skipping.
# File Akir.txt already exists. Skipping.
# File Akrobatik.txt already exists. Skipping.
# File Alias (musician).txt already exists. Skipping.
# File Hoodie Allen.txt already exists. Skipping.
# File Amil.txt already exists. Skipping.
# File Antoinette (rapper).txt already exists. Skipping.
# File Aone Beats.txt already exists. Skipping.
# File Apache (rapper).txt already exists. Skipping.
# File Apathy (rapper).txt already exists. Skipping.
# File AR-Ab.txt already exists. Skipping.
# File AraabMuzik.txt already exists. Skipping.
# File Arkatech Beatz.txt already exists. Skipping.
# File M. K. Asante.txt already exists. Skipping.
# File Asheru.txt already exists. Skipping.
# File The Audible Doctor.txt already exists. Skipping.
# File Awkwafina.txt already exists. Skipping.
# File AZ (rapper).txt already exists. Skipping.
# File Apani B. Fly.txt already exists. Skipping.
# File DJ Babu.txt already exists. Skipping.
# File Bahamadia.txt already exists. Skipping.
# File Marty Baller.txt already exists. Skipping.
# File Charli Baltimore.txt already exists. Skipping.
# File Afrika Bambaataa.txt already exists. Skipping.
# File Bodega Bamz.txt already exists. Skipping.
# File Azealia Banks.txt already exists. Skipping.
# File Lloyd Banks.txt already exists. Skipping.
# File MC Paul Barman.txt already exists. Skipping.
# File Mark Batson.txt already exists. Skipping.
# File The Beat Bully.txt already exists. Skipping.
# File Jahlil Beats.txt already exists. Skipping.
# File Beedie (rapper).txt already exists. Skipping.
# File Benny the Butcher.txt already exists. Skipping.
# File Benzino.txt already exists. Skipping.
# File Big Body Bes.txt already exists. Skipping.
# File Big Daddy Kane.txt already exists. Skipping.
# File Big Pun.txt already exists. Skipping.
# File Big Shug.txt already exists. Skipping.
# File Bkorn.txt already exists. Skipping.
# File Black Child.txt already exists. Skipping.
# File Black Rob.txt already exists. Skipping.
# File Black Thought.txt already exists. Skipping.
# File Memphis Bleek.txt already exists. Skipping.
# File Blockhead (music producer).txt already exists. Skipping.
# File Action Bronson.txt already exists. Skipping.
# File Bronx Style Bob.txt already exists. Skipping.
# File Foxy Brown (rapper).txt already exists. Skipping.
# File Tommy Brown (record producer).txt already exists. Skipping.
# File Ron Browz.txt already exists. Skipping.
# File Buckshot (rapper).txt already exists. Skipping.
# File Buckwild (music producer).txt already exists. Skipping.
# File Joe Budden.txt already exists. Skipping.
# File Dai Burger.txt already exists. Skipping.
# File Cage (rapper).txt already exists. Skipping.
# File Crystal Caines.txt already exists. Skipping.
# File Call Me Ace.txt already exists. Skipping.
# File Cam'ron.txt already exists. Skipping.
# File Canibus.txt already exists. Skipping.
# File Don Cannon.txt already exists. Skipping.
# File Capella Grey.txt already exists. Skipping.
# File Capital Steez.txt already exists. Skipping.
# File Capone (rapper).txt already exists. Skipping.
# File Cappadonna.txt already exists. Skipping.
# File Kid Capri.txt already exists. Skipping.
# File Cardi B.txt already exists. Skipping.
# File Cardiak.txt already exists. Skipping.
# File Casanova (rapper).txt already exists. Skipping.
# File Cassidy (rapper).txt already exists. Skipping.
# File Grandmaster Caz.txt already exists. Skipping.
# File Cazwell.txt already exists. Skipping.
# File Lil' Cease.txt already exists. Skipping.
# File John Cena.txt already exists. Skipping.
# File Ceschi.txt already exists. Skipping.
# File DJ Charlie Chase.txt already exists. Skipping.
# File Chinx.txt already exists. Skipping.
# File DJ Chuck Chillout.txt already exists. Skipping.
# File Chyskillz.txt already exists. Skipping.
# File CJ (rapper).txt already exists. Skipping.
# File Clams Casino (musician).txt already exists. Skipping.
# File Sean Combs.txt already exists. Skipping.
# File Consequence (rapper).txt already exists. Skipping.
# File Conway the Machine.txt already exists. Skipping.
# File Cool C.txt already exists. Skipping.
# File Cordae.txt already exists. Skipping.
# File Cousin Stizz.txt already exists. Skipping.
# File Keef Cowboy.txt already exists. Skipping.
# File Jay Critch.txt already exists. Skipping.
# File Cuban Link.txt already exists. Skipping.
# File D-Nice.txt already exists. Skipping.
# File Daddy-O (rapper).txt already exists. Skipping.
# File Danger Mouse (musician).txt already exists. Skipping.
# File Danny Boy (rapper).txt already exists. Skipping.
# File Dash (rapper).txt already exists. Skipping.
# File Desiigner.txt already exists. Skipping.
# File Diabolic (rapper).txt already exists. Skipping.
# File Kosha Dillz.txt already exists. Skipping.
# File Flipp Dinero.txt already exists. Skipping.
# File Disco King Mario.txt already exists. Skipping.
# File DJ Disco Wiz.txt already exists. Skipping.
# File DMX.txt already exists. Skipping.
# File Tim Dog.txt already exists. Skipping.
# File B. Dolan.txt already exists. Skipping.
# File Don Q (rapper).txt already exists. Skipping.
# File MF Doom.txt already exists. Skipping.
# File Dot da Genius.txt already exists. Skipping.
# File Drag-On.txt already exists. Skipping.
# File DJ Drama.txt already exists. Skipping.
# File Dub-L.txt already exists. Skipping.
# File Dutch ReBelle.txt already exists. Skipping.
# File DVLP.txt already exists. Skipping.
# File Smoke DZA.txt already exists. Skipping.
# File E.D.I. Mean.txt already exists. Skipping.
# File East Flatbush Project.txt already exists. Skipping.
# File Dave East.txt already exists. Skipping.
# File Ed O.G..txt already exists. Skipping.
# File El-P.txt already exists. Skipping.
# File Eric B..txt already exists. Skipping.
# File Esoteric (rapper).txt already exists. Skipping.
# File Eve (rapper).txt already exists. Skipping.
# File Eyenine.txt already exists. Skipping.
# File Fabolous.txt already exists. Skipping.
# File Mickey Factz.txt already exists. Skipping.
# File Fat Joe.txt already exists. Skipping.
# File Hussein Fatal.txt already exists. Skipping.
# File Felly.txt already exists. Skipping.
# File ASAP Ferg.txt already exists. Skipping.
# File Grandmaster Flash.txt already exists. Skipping.
# File CJ Fly.txt already exists. Skipping.
# File Focus....txt already exists. Skipping.
# File Q Da Fool.txt already exists. Skipping.
# File Fivio Foreign.txt already exists. Skipping.
# File Freddie Foxxx.txt already exists. Skipping.
# File Njena Reddd Foxxx.txt already exists. Skipping.
# File Sage Francis.txt already exists. Skipping.
# File Harry Fraud.txt already exists. Skipping.
# File Fred the Godson.txt already exists. Skipping.
# File Freekey Zekey.txt already exists. Skipping.
# File Frenchie (rapper).txt already exists. Skipping.
# File Fresh Kid Ice.txt already exists. Skipping.
# File Doug E. Fresh.txt already exists. Skipping.
# File Funkmaster Flex.txt already exists. Skipping.
# File Ty Fyffe.txt already exists. Skipping.
# File G Koop.txt already exists. Skipping.
# File Heather B. Gardner.txt already exists. Skipping.
# File Mic Geronimo.txt already exists. Skipping.
# File GFMBryyce.txt already exists. Skipping.
# File Ghostface Killah.txt already exists. Skipping.
# File Godfather Don.txt already exists. Skipping.
# File Irv Gotti.txt already exists. Skipping.
# File Jean Grae.txt already exists. Skipping.
# File Grafh.txt already exists. Skipping.
# File Dame Grease.txt already exists. Skipping.
# File MF Grimm.txt already exists. Skipping.
# File Cory Gunz.txt already exists. Skipping.
# File Guru (rapper).txt already exists. Skipping.
# File GZA.txt already exists. Skipping.
# File Half a Mill.txt already exists. Skipping.
# File Sleepy Hallow.txt already exists. Skipping.
# File Charles Hamilton (rapper).txt already exists. Skipping.
# File Andre Harrell.txt already exists. Skipping.
# File Havoc (musician).txt already exists. Skipping.
# File Emile Haynie.txt already exists. Skipping.
# File Heavy D.txt already exists. Skipping.
# File Hell Rell.txt already exists. Skipping.
# File Samuel T. Herring.txt already exists. Skipping.
# File Chad Hugo.txt already exists. Skipping.
# File DJ Hurricane.txt already exists. Skipping.
# File Ice Spice.txt already exists. Skipping.
# File Ill Bill.txt already exists. Skipping.
# File Inspectah Deck.txt already exists. Skipping.
# File Islord.txt already exists. Skipping.
# File J.I the Prince of N.Y.txt already exists. Skipping.
# File J57 (rapper).txt already exists. Skipping.
# File Ja Rule.txt already exists. Skipping.
# File Jadakiss.txt already exists. Skipping.
# File Ms. Jade.txt already exists. Skipping.
# File Mike Jaggerr.txt already exists. Skipping.
# File Jam Master Jay.txt already exists. Skipping.
# File Jasiri X.txt already exists. Skipping.
# File Jay-Z.txt already exists. Skipping.
# File Jaz-O.txt already exists. Skipping.
# File MC Jazzy Jeff.txt already exists. Skipping.
# File DJ Jazzy Joyce.txt already exists. Skipping.
# File MC Jin.txt already exists. Skipping.
# File Jipsta.txt already exists. Skipping.
# File Joey Badass.txt already exists. Skipping.
# File Chilla Jones.txt already exists. Skipping.
# File Serius Jones.txt already exists. Skipping.
# File JPEGMafia.txt already exists. Skipping.
# File Junglepussy.txt already exists. Skipping.
# File Just Blaze.txt already exists. Skipping.
# File Just-Ice.txt already exists. Skipping.
# File Ka$hdami.txt already exists. Skipping.
# File Kangol Kid.txt already exists. Skipping.
# File Kastro (rapper).txt already exists. Skipping.
# File DJ Kay Slay.txt already exists. Skipping.
# File Kemba (rapper).txt already exists. Skipping.
# File Jamie Kennedy.txt already exists. Skipping.
# File Wiz Khalifa.txt already exists. Skipping.
# File Killa Sin.txt already exists. Skipping.
# File Kirk Knight.txt already exists. Skipping.
# File Tate Kobang.txt already exists. Skipping.
# File Kool G Rap.txt already exists. Skipping.
# File Kool Moe Dee.txt already exists. Skipping.
# File KRS-One.txt already exists. Skipping.
# File Talib Kweli.txt already exists. Skipping.
# File Big L.txt already exists. Skipping.
# File Coke La Rock.txt already exists. Skipping.
# File Scott La Rock.txt already exists. Skipping.
# File Lady B.txt already exists. Skipping.
# File Lady Crush.txt already exists. Skipping.
# File Al Sherrod Lambert.txt already exists. Skipping.
# File Lamiere.txt already exists. Skipping.
# File Knero Lapaé.txt already exists. Skipping.
# File Larry Larr.txt already exists. Skipping.
# File Sabor Latino.txt already exists. Skipping.
# File Lee on the Beats.txt already exists. Skipping.
# File HeeSun Lee.txt already exists. Skipping.
# File Trip Lee.txt already exists. Skipping.
# File Le1f.txt already exists. Skipping.
# File Johan Lenox.txt already exists. Skipping.
# File Coi Leray.txt already exists. Skipping.
# File Alrad Lewis.txt already exists. Skipping.
# File Rob Lewis (record producer).txt already exists. Skipping.
# File Mr. Lif.txt already exists. Skipping.
# File Like (record producer).txt already exists. Skipping.
# File Lil Dicky.txt already exists. Skipping.
# File Lil Mama.txt already exists. Skipping.
# File Lil Peep.txt already exists. Skipping.
# File Lil Tjay.txt already exists. Skipping.
# File Lil' Kim.txt already exists. Skipping.
# File Lin Que.txt already exists. Skipping.
# File Ex-plicit linez.txt already exists. Skipping.
# File Dusty Locane.txt already exists. Skipping.
# File Nicholas Loftin.txt already exists. Skipping.
# File DJ Logic.txt already exists. Skipping.
# File Sheek Louch.txt already exists. Skipping.
# File Louis Logic.txt already exists. Skipping.
# File Ed Lover.txt already exists. Skipping.
# File Jan Lucanus.txt already exists. Skipping.
# File Joyner Lucas.txt already exists. Skipping.
# File MC Lyte.txt already exists. Skipping.
# File M-Dot.txt already exists. Skipping.
# File Remy Ma.txt already exists. Skipping.
# File China Mac.txt already exists. Skipping.
# File Mach-Hommy.txt already exists. Skipping.
# File Craig Mack.txt already exists. Skipping.
# File Kellee Maize.txt already exists. Skipping.
# File Malik B..txt already exists. Skipping.
# File Roc Marciano.txt already exists. Skipping.
# File Biz Markie.txt already exists. Skipping.
# File Marley Marl.txt already exists. Skipping.
# File Brother Marquis.txt already exists. Skipping.
# File Skizzy Mars.txt already exists. Skipping.
# File Theo Martins.txt already exists. Skipping.
# File Mase.txt already exists. Skipping.
# File Masta Killa.txt already exists. Skipping.
# File Mathematics (producer).txt already exists. Skipping.
# File Ivan Matias.txt already exists. Skipping.
# File Lady May (rapper).txt already exists. Skipping.
# File Darryl McDaniels.txt already exists. Skipping.
# File McGruff (rapper).txt already exists. Skipping.
# File Megahertz (record producer).txt already exists. Skipping.
# File Melle Mel.txt already exists. Skipping.
# File Method Man.txt already exists. Skipping.
# File Mike D.txt already exists. Skipping.
# File Mikey D.txt already exists. Skipping.
# File Derrick Milano.txt already exists. Skipping.
# File Meek Mill.txt already exists. Skipping.
# File Mac Miller.txt already exists. Skipping.
# File Jae Millz.txt already exists. Skipping.
# File Mims (rapper).txt already exists. Skipping.
# File Andy Mineo.txt already exists. Skipping.
# File Mr. Muthafuckin' eXquire.txt already exists. Skipping.
# File Mr. Mixx.txt already exists. Skipping.
# File Easy Mo Bee.txt already exists. Skipping.
# File Pharoahe Monch.txt already exists. Skipping.
# File French Montana.txt already exists. Skipping.
# File Mos Def.txt already exists. Skipping.
# File Ali Shaheed Muhammad.txt already exists. Skipping.
# File Uncle Murda.txt already exists. Skipping.
# File Keith Murray.txt already exists. Skipping.
# File Myzery.txt already exists. Skipping.
# File N.O.R.E..txt already exists. Skipping.
# File Nas.txt already exists. Skipping.
# File ASAP Nast.txt already exists. Skipping.
# File Necro (rapper).txt already exists. Skipping.
# File Bishop Nehru.txt already exists. Skipping.
# File Neo da Matrix.txt already exists. Skipping.
# File Nine (rapper).txt already exists. Skipping.
# File Nitty (musician).txt already exists. Skipping.
# File No Malice.txt already exists. Skipping.
# File Young Noble.txt already exists. Skipping.
# File NOE (rapper).txt already exists. Skipping.
# File Princess Nokia.txt already exists. Skipping.
# File The Notorious B.I.G..txt already exists. Skipping.
# File O.C. (rapper).txt already exists. Skipping.
# File Ol' Dirty Bastard.txt already exists. Skipping.
# File Shaquille O'Neal.txt already exists. Skipping.
# File Oompa (rapper).txt already exists. Skipping.
# File Joell Ortiz.txt already exists. Skipping.
# File Styles P.txt already exists. Skipping.
# File Prince Paul (producer).txt already exists. Skipping.
# File Felicia Pearson.txt already exists. Skipping.
# File Pepa (rapper).txt already exists. Skipping.
# File Percee P.txt already exists. Skipping.
# File Pete Rock.txt already exists. Skipping.
# File Petey Pablo.txt already exists. Skipping.
# File Thee Phantom.txt already exists. Skipping.
# File Phife Dawg.txt already exists. Skipping.
# File Stelios Phili.txt already exists. Skipping.
# File Jamal Phillips.txt already exists. Skipping.
# File Phresher.txt already exists. Skipping.
# File Pras.txt already exists. Skipping.
# File DJ Premier.txt already exists. Skipping.
# File Sean Price.txt already exists. Skipping.
# File Prince Whipper Whip.txt already exists. Skipping.
# File Princess Superstar.txt already exists. Skipping.
# File Prodigy (rapper).txt already exists. Skipping.
# File Large Professor.txt already exists. Skipping.
# File Prolyphic.txt already exists. Skipping.
# File Pumpkinhead (rapper).txt already exists. Skipping.
# File Pusha T.txt already exists. Skipping.
# File Q-Tip (musician).txt already exists. Skipping.
# File Queen Latifah.txt already exists. Skipping.
# File Queen Pen.txt already exists. Skipping.
# File Radamiz.txt already exists. Skipping.
# File Rah Swish.txt already exists. Skipping.
# File Rakim.txt already exists. Skipping.
# File Kyle Rapps.txt already exists. Skipping.
# File Hell Razah.txt already exists. Skipping.
# File Oryn the Rebel.txt already exists. Skipping.
# File Red Café.txt already exists. Skipping.
# File Redman (rapper).txt already exists. Skipping.
# File Reks.txt already exists. Skipping.
# File Salaam Remi.txt already exists. Skipping.
# File Moshe Reuven.txt already exists. Skipping.
# File Busta Rhymes.txt already exists. Skipping.
# File DJ Richie Rich.txt already exists. Skipping.
# File Chubb Rock.txt already exists. Skipping.
# File Rockwilder.txt already exists. Skipping.
# File ASAP Rocky.txt already exists. Skipping.
# File Roscoe (rapper).txt already exists. Skipping.
# File Asher Roth.txt already exists. Skipping.
# File Elle Royal.txt already exists. Skipping.
# File David Rush (rapper).txt already exists. Skipping.
# File RZA.txt already exists. Skipping.
# File Sadat X.txt already exists. Skipping.
# File Saga (rapper).txt already exists. Skipping.
# File Saigon (rapper).txt already exists. Skipping.
# File Salt (rapper).txt already exists. Skipping.
# File Juelz Santana.txt already exists. Skipping.
# File Sauce Money.txt already exists. Skipping.
# File Scar Lip.txt already exists. Skipping.
# File Schoolly D.txt already exists. Skipping.
# File Jill Scott (singer).txt already exists. Skipping.
# File DJ Scratch.txt already exists. Skipping.
# File Sensational (musician).txt already exists. Skipping.
# File Sensato del Patio.txt already exists. Skipping.
# File Erick Sermon.txt already exists. Skipping.
# File Sha Money XL.txt already exists. Skipping.
# File Jonathan Shecter.txt already exists. Skipping.
# File Sheff G.txt already exists. Skipping.
# File Bobby Shmurda.txt already exists. Skipping.
# File Shock G.txt already exists. Skipping.
# File Kiing Shooter.txt already exists. Skipping.
# File Shyne.txt already exists. Skipping.
# File Beanie Sigel.txt already exists. Skipping.
# File Silkski.txt already exists. Skipping.
# File Siya.txt already exists. Skipping.
# File DJ Skee.txt already exists. Skipping.
# File Lil Skies.txt already exists. Skipping.
# File Skinnyfromthe9.txt already exists. Skipping.
# File Slaine (rapper).txt already exists. Skipping.
# File Rashad Smith (producer).txt already exists. Skipping.
# File Will Smith.txt already exists. Skipping.
# File Pop Smoke.txt already exists. Skipping.
# File CL Smooth.txt already exists. Skipping.
# File Sam Sneed.txt already exists. Skipping.
# File Fresh Kid Ice.txt already exists. Skipping.
# File Brother Marquis.txt already exists. Skipping.
# File Mr. Mixx.txt already exists. Skipping.

# %% [markdown]
# > Finally, we can create our own corpus (see Ch. 2 Sec. 1.9 for more details):
# >    * create a list of file names `file_list` and order them with the same order in `df_rappers`, e.g., 03_Greedo.txt first, 22Gz.txt second, etc.
# >    * use the function `PlaintextCorpusReader` from `nltk.corpus` to create the rapper corpus.
# >    * use the function `nltk.Text()` as follows `nltk.Text(YOUR_CORPUS_HERE.words())`.
# >
# > Now you can use this nltk Text object as any other you've seen in the examples of Chapter 1!!

# %% [markdown]
# ### 2.3 Exercises: NLPP Chapter 1
# (the stuff that might be due in an upcoming assignment)
#
# The following exercises are from Chapter 1 but we are going to use them to study the rapper Wikipedia text.

# %% [markdown]
# > *Exercise 1*: Exploratory analysis
# >
# > * Try out the `concordance` method, using the rapper Wikipedia text and a word of your own choosing.
# > * Also try out the `similar` and `common_contexts` methods, again with any words you like.
# > * Create the rapper Wikipedia version of a dispersion plot:
# >    1. try your own version of the dispersion plot (use any set of words you like but remember to explain what you observe).
# > * What is a bigram? How does it relate to `collocations`. Explain in your own words.
# >    1. Compute the collocations on the rapper Wikipedia Text.
# > * Review the discussion of conditionals in Sec. 4. Find all words in the rapper Wikipedia Text starting with the letter *h*. Show the first 5 in alphabetical order. Try with a few other letters. Any fun examples of top-five words?
# > * Use `.index()` to find the index of the word *Snoop*. You'll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.
# > * Review the discussion of looping with conditions in Sec 4. Use a combination of `for` and `if` statements to loop over the words of the rapper Wikipedia text and print the 5 longest uppercase words, one per line.

# %% [markdown]
# > *Exercise 2*: Basic stats
# >
# > * How many tokens are there in the rapper Wikipedia text? How many distinct tokens are there?
# > * Explain in your own words what aspect of language _lexical diversity_ describes.
# >     1. Compute the lexical diversity of the rapper Wikipedia text;
# >     2. Compute the lexical diversity related to West (coast) and East (coast). Comment on your results.
# > * Create frequency distributions for the rapper Wikipedia text, including the cumulative frequency plot for the 75 most common tokens.
# > * Find all the four-letter tokens in the rapper Wikipedia text. With the help of a frequency distribution (FreqDist), show these tokens in decreasing order of frequency.
# > * What does the following code do? `sum(len(w) for w in rapperWiki)` Can you use it to work out the average token length of the rapper Wikipedia text?
# > * Define a function:
# >     1. called `vocab_size(text)` that has a single parameter for the `text`, and which returns the vocabulary size of the text. Apply it to the rapper Wikipedia text;
# >     2. `percent(word, text)` that calculates how often a given `word` occurs in a `text`, and expresses the result as a percentage. Apply it to the rapper Wikipedia Text to compute the percentage for *Dre*.

# %% [markdown]
# # Part 3: Working with NLTK and other types of text
#
# So far, we've worked with text from the rapper Wikipedia. But that's not the only source of text in the universe. In fact, it's far from it. Chapter 2 in NLPP is all about getting access to nicely curated texts that you can find built into NLTK.
# >
# > Reading: NLPP Chapter 2, Sec. 1 - 4.
# >

# %% [markdown]
# > *Exercises*: NLPP Chapter 2\. (other stuff that might be due in an assignment)
# >
# > * Solve exercise 4, 8, 11, 15, 16, 17, 18 in NLPP, section 2.8\. As always, I recommend you write up your solutions nicely in a `notebook`.
# > * Work through exercise 2.8.23 on Zipf's law. [Zipf's law](https://en.wikipedia.org/wiki/Zipf%27s_law) connects to a property of the Barabasi-Albert networks. Which one? Take a look at [this article](https://www.hpl.hp.com/research/idl/papers/ranking/adamicglottometrics.pdf) and write a paragraph or two describing other important instances of power-laws found on the internet.
# >
